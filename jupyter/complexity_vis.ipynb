# %%
import pandas as pd
import matplotlib.pyplot as plt

load_data = pd.read_csv('load_measure.csv')
vect_data = pd.read_csv('vectorize_measure.csv')

# %%
load_data
# Out:
#     tweets         time         mem
# 0     9431    13.506043   112977362
# 1    19234    21.035608   119657127
# 2    41015    37.240156   134348260
# 3    79139    69.703123   159138068
# 4   161137   139.240449   214089824
# 5   324798   328.957650   323931771
# 6   657700   717.132124   547049663
# 7  1309538  1465.654840   982332357
# 8  2630811  3118.455002  1869891086

# %%
vect_data
# Out:
#     tweets      time        mem     cols
# 0     9431  1.397858  109493692    27492
# 1    19234  1.203164  111858977    48630
# 2    41015  1.245260  116522726    85176
# 3    79139  1.204859  123943174   137885
# 4   161137  1.705342  139463642   239228
# 5   324798  2.054166  169717398   425641
# 6   657700  2.903569  228727241   764098
# 7  1309538  3.439508  340403692  1366028

# %%
plt.plot(vect_data['cols'], vect_data['mem'])

# %%
# Vocabulary should not be increasing linearly! this is not what I was promised
# mem increases linearly in function of cols/tweets ... as if each tweet is adding at least one new, unique word not found in any other tweet: URLs!?
